# %% [markdown]
# ## SpreadSheet

# %% [markdown]
# ### SH_H20

# %%
#Import the Libs
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#Importing the Data
SH_Data = pd.read_excel('C:\\Users\\USER\\OneDrive\\CB\\ALX\\Data Science\\Integrated Exams\\Exam_Part_I_data\\Exam_Part_I_data 5\\SH_H2O_SAFE.xlsx', sheet_name=None)
SH_Data
# Out:
# {'Table format':      Goal  Target Indicator   SeriesCode  \
#  0       6     6.1     6.1.1  SH_H2O_SAFE
#  1       6     6.1     6.1.1  SH_H2O_SAFE
#  2       6     6.1     6.1.1  SH_H2O_SAFE
#  3       6     6.1     6.1.1  SH_H2O_SAFE
#  4       6     6.1     6.1.1  SH_H2O_SAFE
#  ..    ...     ...       ...          ...
#  408     6     6.1     6.1.1  SH_H2O_SAFE
#  409     6     6.1     6.1.1  SH_H2O_SAFE
#  410     6     6.1     6.1.1  SH_H2O_SAFE
#  411     6     6.1     6.1.1  SH_H2O_SAFE
#  412     6     6.1     6.1.1  SH_H2O_SAFE
#
#                                       SeriesDescription  GeoAreaCode  \
#  0    Proportion of population using safely managed ...            4
#  1    Proportion of population using safely managed ...            4
#  2    Proportion of population using safely managed ...            4
#  3    Proportion of population using safely managed ...            8
#  4    Proportion of population using safely managed ...           12
# ...

# %%
SH_Data['Table format'].head()
# Out:
#    Goal  Target Indicator   SeriesCode  \
# 0     6     6.1     6.1.1  SH_H2O_SAFE
# 1     6     6.1     6.1.1  SH_H2O_SAFE
# 2     6     6.1     6.1.1  SH_H2O_SAFE
# 3     6     6.1     6.1.1  SH_H2O_SAFE
# 4     6     6.1     6.1.1  SH_H2O_SAFE
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Proportion of population using safely managed ...            4
# 1  Proportion of population using safely managed ...            4
# 2  Proportion of population using safely managed ...            4
# 3  Proportion of population using safely managed ...            8
# 4  Proportion of population using safely managed ...           12
#
#    GeoAreaName Location Reporting Type    Units  ...      2013      2014  \
# 0  Afghanistan  ALLAREA              G  PERCENT  ...  22.03447  22.94430
# 1  Afghanistan    RURAL              G  PERCENT  ...  19.36433  20.29407
# 2  Afghanistan    URBAN              G  PERCENT  ...  30.31965  31.07307
# ...

# %% [markdown]
# ##### Question 2
# How many unique values (or GeoAreaNames)  are in the `GeoAreaName` column on the `Table format` sheet?

# %%
SH_Data['Table format']['GeoAreaName'].nunique()
# Out:
# 198

# %% [markdown]
# #### Question 3
# How many rows are there in the `Table format` sheet for each of the three types of `Locations`?

# %%
SH_Data['Table format'].groupby(by='Location').agg({'Location': 'count'})
# Out:
#           Location
# Location
# ALLAREA        180
# RURAL          102
# URBAN          131

# %% [markdown]
# #### Question 4
# Consider the data we have on Afghanistan, for the years 2000-2022. Which of the following statements is most correct?

# %%
SH_Data['Record format'].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9317 entries, 0 to 9316
# Data columns (total 21 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Goal               9317 non-null   int64
#  1   Target             9317 non-null   float64
#  2   Indicator          9317 non-null   object
#  3   SeriesCode         9317 non-null   object
#  4   SeriesDescription  9317 non-null   object
#  5   GeoAreaCode        9317 non-null   int64
#  6   GeoAreaName        9317 non-null   object
#  7   TimePeriod         9317 non-null   int64
#  8   Value              9317 non-null   float64
#  9   Time_Detail        9317 non-null   int64
#  10  TimeCoverage       0 non-null      float64
#  11  UpperBound         0 non-null      float64
#  12  LowerBound         0 non-null      float64
#  13  BasePeriod         0 non-null      float64
#  14  Source             9317 non-null   object
#  15  GeoInfoUrl         0 non-null      float64
# ...

# %%
SH_Data['Record format'].head()
# Out:
#    Goal  Target Indicator   SeriesCode  \
# 0     6     6.1     6.1.1  SH_H2O_SAFE
# 1     6     6.1     6.1.1  SH_H2O_SAFE
# 2     6     6.1     6.1.1  SH_H2O_SAFE
# 3     6     6.1     6.1.1  SH_H2O_SAFE
# 4     6     6.1     6.1.1  SH_H2O_SAFE
#
#                                    SeriesDescription  GeoAreaCode  \
# 0  Proportion of population using safely managed ...            4
# 1  Proportion of population using safely managed ...            4
# 2  Proportion of population using safely managed ...            4
# 3  Proportion of population using safely managed ...            4
# 4  Proportion of population using safely managed ...            4
#
#    GeoAreaName  TimePeriod     Value  Time_Detail  ...  UpperBound  \
# 0  Afghanistan        2000  11.09333         2000  ...         NaN
# 1  Afghanistan        2001  11.10522         2001  ...         NaN
# 2  Afghanistan        2002  12.00773         2002  ...         NaN
# ...

# %%
Afghan_data = SH_Data['Record format'][SH_Data['Record format']['GeoAreaName'] == "Afghanistan"][['TimePeriod', 'Value', 'Location']]

# %%
Afghan_data.info()
Afghan_data.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69 entries, 0 to 68
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   TimePeriod  69 non-null     int64
#  1   Value       69 non-null     float64
#  2   Location    69 non-null     object
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ KB
#    TimePeriod     Value Location
# 0        2000  11.09333  ALLAREA
# 1        2001  11.10522  ALLAREA
# 2        2002  12.00773  ALLAREA
# 3        2004  13.81868  ALLAREA
# 4        2003  12.90992  ALLAREA

# %% [markdown]
# *In Afghanistan in 2000, the number of people in urban areas using safely managed drinking was more than twice as many as in rural areas?*

# %%
Afghan_data[Afghan_data['TimePeriod'] == 2000].sort_values(by= 'Value')
# Out:
#     TimePeriod     Value Location
# 44        2000   8.20749    RURAL
# 0         2000  11.09333  ALLAREA
# 53        2000  21.27858    URBAN

# %%
Afghan_data[Afghan_data['TimePeriod'] == 2000].sort_values(by= 'Value')['Value'][53] /Afghan_data[Afghan_data['TimePeriod'] == 2000].sort_values(by= 'Value')['Value'][44]
# Out:
# 2.592580679355077

# %% [markdown]
# *21.28 million people in Urban areas in Afghanistan had access to safely managed drinking water in 2000*

# %% [markdown]
# ***Trends***
#
# *Overall, the proportion of the Afghan population using safely managed drinking water (including both rural and urban areas), has almost tripled between 2000 and 2022.*

# %%
sns.lineplot(data=Afghan_data, x='TimePeriod', y='Value', hue='Location')
plt.show()

# %% [markdown]
# ### SDG_10_7_3

# %%
#importing the Data
SDG_10 = pd.read_excel(r'C:\Users\USER\OneDrive\CB\ALX\Data Science\Integrated Exams\Exam_Part_I_data\Exam_Part_I_data 5\SDG_10_7_3.xlsx', sheet_name= None)

# %%
SDG_10.keys()
# Out:
# dict_keys(['CodeDescriptions', 'Goal10', 'Pivot Table 5'])

# %%
SDG_10['Goal10'].head()
# Out:
#    Goal  Target Indicator   SeriesCode  \
# 0    10    10.7    10.7.3  SM_DTH_MIGR
# 1    10    10.7    10.7.3  SM_DTH_MIGR
# 2    10    10.7    10.7.3  SM_DTH_MIGR
# 3    10    10.7    10.7.3  SM_DTH_MIGR
# 4    10    10.7    10.7.3  SM_DTH_MIGR
#
#                                    SeriesDescription  GeoAreaCode GeoAreaName  \
# 0  Total deaths and disappearances recorded durin...            1       World
# 1  Total deaths and disappearances recorded durin...            1       World
# 2  Total deaths and disappearances recorded durin...            1       World
# 3  Total deaths and disappearances recorded durin...            1       World
# 4  Total deaths and disappearances recorded durin...            1       World
#
#    TimePeriod  Value  Time_Detail  ...   .10   .11   .12   .13  .14   .15  \
# 0        2014   5548         2014  ...   NaN   NaN   NaN   NaN  NaN   NaN
# 1        2015   6750         2015  ...   NaN   NaN   NaN   NaN  NaN   NaN
# ...

# %% [markdown]
# ##### Question 5
# Which one of these countries has the highest number of data points in our dataset?

# %%
Count_rows_by_coountry = SDG_10['Goal10'].groupby(by= 'GeoAreaName').agg(
    n = ('Goal', 'count')
).sort_values(by= 'n', ascending= False)

# %%
Count_rows_by_coountry.loc[['Chad', 'Chile', 'Algeria', 'Angola']].sort_values(by='n', ascending=False)
# Out:
#               n
# GeoAreaName
# Algeria      10
# Chile         6
# Chad          5
# Angola        2

# %% [markdown]
# ##### Question 6
# Which year has the most data points in this dataset?

# %%
Rows_count_by_Timeperiod = SDG_10['Goal10'].groupby(
    by='TimePeriod'
).agg(
    n = ('TimePeriod', 'count')
)

# %%
Rows_count_by_Timeperiod.sort_values(
    by='n',
    ascending= False
)
# Out:
#               n
# TimePeriod
# 2018        105
# 2022        104
# 2023         96
# 2019         93
# 2021         90
# 2017         85
# 2020         82
# 2016         80
# 2015         78
# 2014         51

# %% [markdown]
# ##### Question 7
# *The GeoAreaName column contains different levels of aggregation, ranging from country, to subregions, to the World.*
#
# *Determine the average number of ‘Total deaths and disappearances recorded during migration’ per GeoAreaName entry, over the period 2018-2023. Express this GeoAreaName average as a proportion of the World average over that time period. What is the proportion that forms the largest share?*

# %%
Country_agg = SDG_10['Goal10'].groupby(
    by='GeoAreaName'
).agg(
    n = ('TimePeriod', 'count'),
    avg = ('Value', 'mean')
)

# %%
Country_agg.sort_values(
    by= 'avg',
    ascending=False
)
# Out:
#                            n     avg
# GeoAreaName
# World                     10  6290.4
# Libya                     10  1994.9
# Northern Africa           10   601.0
# Sub-Saharan Africa        10   480.4
# United States of America  10   433.6
# ...                       ..     ...
# Singapore                  1     1.0
# Switzerland                2     1.0
# Latvia                     1     1.0
# United Arab Emirates       1     1.0
# Republic of Moldova        1     1.0
#
# [163 rows x 2 columns]

# %%
world_avg = Country_agg['avg'].loc['World']
world_avg
#Adding the proportion  Col
Country_agg['Proportions'] = (Country_agg['avg']/ world_avg).map(lambda x: f"{x:.2%}")

# %%
Country_agg.sort_values(
    by= 'avg',
    ascending= False
)
# Out:
#                            n     avg Proportions
# GeoAreaName
# World                     10  6290.4     100.00%
# Libya                     10  1994.9      31.71%
# Northern Africa           10   601.0       9.55%
# Sub-Saharan Africa        10   480.4       7.64%
# United States of America  10   433.6       6.89%
# ...                       ..     ...         ...
# Singapore                  1     1.0       0.02%
# Switzerland                2     1.0       0.02%
# Latvia                     1     1.0       0.02%
# United Arab Emirates       1     1.0       0.02%
# Republic of Moldova        1     1.0       0.02%
#
# [163 rows x 3 columns]

# %% [markdown]
# #### Question 8
#
# *Create a line graph that includes the following regions (also in GeoAreaName) over the period 2014-2023: Eastern Africa, Eastern Europe, Northern Africa, Northern America and Northern Europe*
#
# *Which region shows the sharpest decline in the number of `Total deaths and disappearances recorded during migration` in 2020?*

# %%
#Getting the Data
Quiz_8_Data = SDG_10['Goal10'][['GeoAreaName', 'Value', 'TimePeriod']]

#Filtering 
Quiz_8_Data = Quiz_8_Data[Quiz_8_Data['GeoAreaName'].isin(['Eastern Africa', 'Eastern Europe', 'Northern Africa', 'Northern America', 'Northern Europe'])]

# %%
# Out:
#           GeoAreaName  Value  TimePeriod
# 56     Eastern Africa    322        2014
# 57     Eastern Africa    198        2015
# 58     Eastern Africa    247        2016
# 59     Eastern Africa    131        2017
# 60     Eastern Africa    252        2018
# 61     Eastern Africa     69        2019
# 62     Eastern Africa    168        2020
# 63     Eastern Africa    149        2021
# 64     Eastern Africa     90        2022
# 65     Eastern Africa    179        2023
# 66    Northern Africa     61        2014
# 67    Northern Africa    733        2015
# 68    Northern Africa   1237        2016
# 69    Northern Africa    987        2017
# 70    Northern Africa    646        2018
# 71    Northern Africa    855        2019
# 72    Northern Africa    131        2020
# 73    Northern Africa    344        2021
# 74    Northern Africa    574        2022
# 75    Northern Africa    442        2023
# 87   Northern America    530        2014
# 88   Northern America    305        2015
# ...

# %%
sns.lineplot(data=Quiz_8_Data, x='TimePeriod', y='Value', hue='GeoAreaName')
# Out:
# <Axes: xlabel='TimePeriod', ylabel='Value'>

# %% [markdown]
# #### Question 9
# *What is the interquartile range for all the data (excluding World) in 2020?*

# %%
Data_ex_world = SDG_10['Goal10'][(SDG_10['Goal10']['GeoAreaName'] != 'World') & (SDG_10['Goal10']['TimePeriod'] == 2020)][['Value', 'TimePeriod', 'GeoAreaName']]

# %%
Q1 = Data_ex_world['Value'].quantile(0.25)
Q3 = Data_ex_world['Value'].quantile(0.75)

IQR = Q3 - Q1
print(f'IQR : {IQR}')
# Out:
# IQR : 123.0

# %% [markdown]
# #### Question 10
# *The UN subregion of North Africa consists of 7 countries at the northernmost part of the continent -- Algeria, Egypt, Libya, Morocco, Sudan, Tunisia, Western Sahara. Knowing this, what is most worrying to you about the regions captured in the dataset?*

# %%
Quiz_10_Data = SDG_10['Goal10'][['GeoAreaName', 'Value', 'TimePeriod']]

Quiz_10_Data = Quiz_10_Data[Quiz_10_Data['GeoAreaName'].isin(['Algeria', 'Egypt', 'Libya', 'Morocco', 'Sudan', 'Tunisia', 'Western Sahara', 'Northern Africa'])]
Quiz_10_Data.isna().sum()
# Out:
# GeoAreaName    0
# Value          0
# TimePeriod     0
# dtype: int64

# %%
sns.lineplot(data=Quiz_10_Data, x='TimePeriod', y='Value', hue='GeoAreaName')
# Out:
# <Axes: xlabel='TimePeriod', ylabel='Value'>
